# %% [markdown]
# <a href="https://colab.research.google.com/github/honggyeong/sw/blob/master/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EA%B8%B0%EC%B4%8804(%EB%B0%98%EB%B3%B5%EB%AC%B8)%EC%9D%98_%ED%95%99%EC%83%9D%EA%B3%B5%EC%9C%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 4. 반복문 (for) **
#
# ![스크린샷 2025-03-11 095744.png](data:image/png;base64,...)

# %% [markdown]
# [실습1] 1~10중 짝수만 출력하는 코드를 작성해 보자

# %%
for num in range(1, 11):
    if num % 2 == 0:
        print(num, "는 짝수입니다.")
# Out:
# 2 는 짝수입니다.
# 4 는 짝수입니다.
# 6 는 짝수입니다.
# 8 는 짝수입니다.
# 10 는 짝수입니다.

# %% [markdown]
# [실습2] 1부터 50까지의 숫자 중 3의 배수이면서 5의 배수인 숫자 출력하기
# *  출력예시<br>
#   15 는 3과 5의 공배수입니다.<br>
#   30 는 3과 5의 공배수입니다.<br>
#   45 는 3과 5의 공배수입니다.<br>

# %%
for num in range(1, 51):

# %% [markdown]
# [실습3]words = ["apple", "banana", "cherry", "grape"] 에서 'a'문자가 포함된 단어만 출력하기<br>
# *  출력예시<br>
#   apple 에는 'a'가 포함되어 있습니다.<br>
#   banana 에는 'a'가 포함되어 있습니다.<br>
#   grape 에는 'a'가 포함되어 있습니다.<br>

# %%
words = ["apple", "banana", "cherry", "grape"]
for (   ) in (     ):
    if (    ) in word:
        print(word, "에는 'a'가 포함되어 있습니다.")

# %% [markdown]
# [실습4] 구구단 리스트가 있을 때 dan_list = [2, 3, 4, 5, 6, 7, 8, 9] 짝수단만 출력하기
#
# *   dan_list를 순회할 for문
# *   해당 단에서 *1, *2, *3 ..을 반복할 for문

# %%
dan_list = [2, 3, 4, 5, 6, 7, 8, 9]  # 구구단 리스트

for  (    ) in dan_list:  # 단(2~9)을 순회
    if dan (         ):  # 짝수 단만 출력
        for num in range(1, 10):  # 1부터 9까지 곱하기
            print(f"{dan} x {num} = {dan * num}")  #포맷 문자열(format string)
        print("-" * 15)  # 구분선
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# ---------------
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# ---------------
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# ---------------
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# ---------------

# %% [markdown]
# **Chapter 4. 반복문 (while) **  ![스크린샷 2025-03-11 101954.png](data:image/png;base64,...)

# %% [markdown]
# [실습1] 리스트에서 특정 값 찾기 (사용자가 입력할 때까지 반복)
#
# *   numbers = [3, 7, 12, 24, 36] 에서 사용자가 입력한 숫자가 있다면 해당 숫자가 있다고 출력하기
# *   사용자가 0을 입력한다면 프로그램 종료
#
# *   <실행예시>
# *   찾을 숫자를 입력하세요 (0 입력 시 종료): 7<br>
# 7은(는) 리스트에 있습니다!<br>
# 찾을 숫자를 입력하세요 (0 입력 시 종료): 5<br>
# 5은(는) 리스트에 없습니다.<br>
# 찾을 숫자를 입력하세요 (0 입력 시 종료): 0<br>
# 프로그램을 종료합니다.

# %%
numbers = [3, 7, 12, 24, 36]  # 숫자 리스트
while True:
    num = int(input("찾을 숫자를 입력하세요 (0 입력 시 종료): "))
    if num == 0:
        print("프로그램을 종료합니다.")
        break

                                                           # f-string을 이용하여 출력해 보자

                                                           # f-string을 이용하여 출력해 보자

# %% [markdown]
#  [실습2] numbers = [10, 15, 22, 33, 40, 55] 리스트에서 짝수만 찾아 새로운 리스트에 저장
#
# *   <힌트>
#
#    while문을 사용해 리스트를 순회합니다. len(numbers)를 활용해 보세요<br>
#   if numbers[i] % 2 == 0: 조건으로 짝수만 even_numbers 리스트에 추가합니다.<br>
#  i += 1을 이용해 리스트 끝까지 검사합니다.
# *   <출력 결과>
#
#  짝수 리스트: [10, 22, 40]

# %%
numbers = [10, 15, 22, 33, 40, 55]  # 숫자 리스트
even_numbers = []  # 짝수만 저장할 리스트
i = 0  # 인덱스 변수

while (             ):                       #i인덱스가 numbers의 항목 수보다 작을 때까지



    i += 1                                    # 인덱스 증가

print("짝수 리스트:", even_numbers)
